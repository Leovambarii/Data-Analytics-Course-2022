# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
df = pd.read_csv('kc_house_data.csv') # Loading data from the file using read_csv
df.head(5) # Printing firt 5 rows of the dataset
#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# After loading the dataset we can see the overall informations that the dataset contains by using head(x) function that show x first rows. We can see the overall structure - indexing, different columns and what type of variables it contains.

# %%
#b) 
list_all = ['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15'] # list of all variables sorted alphabetically
# Defining dataframes which contain categorical or numerical variables
house_categorical_df = df[['condition', 'date', 'grade', 'id', 'view', 'waterfront', 'zipcode']]
house_numerical_df = df[['bathrooms', 'bedrooms', 'floors', 'lat', 'long', 'price', 'sqft_above', 'sqft_basement', 'sqft_living', 'sqft_living15', 'sqft_lot', 'sqft_lot15', 'yr_built', 'yr_renovated']]
pd.Index(list_all)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# By distinguishing variables between categorical and numerical alows analysis dedicated to these types of variables.

# %%
#c)
#Your code:
house_numerical_df.describe() # Using describe() function to generate descriptive statistics


#Hint: Function describe()
# Out:
#           bathrooms      bedrooms        floors           lat          long  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       2.114757      3.370842      1.494309     47.560053   -122.213896
# std        0.770163      0.930062      0.539989      0.138564      0.140828
# min        0.000000      0.000000      1.000000     47.155900   -122.519000
# 25%        1.750000      3.000000      1.000000     47.471000   -122.328000
# 50%        2.250000      3.000000      1.500000     47.571800   -122.230000
# 75%        2.500000      4.000000      2.000000     47.678000   -122.125000
# max        8.000000     33.000000      3.500000     47.777600   -121.315000
#
#               price    sqft_above  sqft_basement   sqft_living  sqft_living15  \
# count  2.161300e+04  21613.000000   21613.000000  21613.000000   21613.000000
# mean   5.400881e+05   1788.390691     291.509045   2079.899736    1986.552492
# ...

# %% [markdown]
# By using describe function() we can see the overall statistics of the informations of the dataset with calculated percentiles. It already allows to see some of the interesting informations - for example:
# * The count describes only how many full records are not null in each column so if every contains the same number it is highly possible that every row contains informations in all columns.
# * The mean for example in bedrooms column is 3.37 so usually sold houses had around 3 bedrooms each,
# however mean sometimes doesn't give valuable information, for example for year renovated it states 84,4 because many houses had never been renovated so their value is 0. - we would need to remove all records containing 0 to get a real mean year.
# * About percentaile information: sqft_above 50% percentaile is 0 so it means that around half of sold houses hadn't any basement.

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.scatter(df['sqft_living'], df['price']) # Creating scatter plot from square footage and price columns of the dataframe
plt.title('Relation of square footage and price')   # Adding title of the plot
plt.xlabel("living sqft")   # Adding label of x variable
plt.ylabel("price") # Adding label of y variable
plt.ticklabel_format(style='plain') # Removing scientific notation (1e6)
plt.show()  # Showing the plot

#Hint plt.scatter

# %% [markdown]
# The scatter plot shows us that there isn't big correlation between square footage of living space and price - there are more variables affection the price of certain house.

# %%
#b)
#Your code:
plt.scatter(df['grade'], df['price'])   # Creating scatter plot from grade and price columns of the dataframe
plt.title('Relation of grade and price')   # Adding title of the plot
plt.xlabel("grade")   # Adding label of x variable
plt.ylabel("price") # Adding label of y variable
plt.ticklabel_format(style='plain') # Removing scientific notation (1e6)
plt.show()  # Showing the plot

plt.scatter(df['bedrooms'], df['price']) # Creating scatter plot from bedrooms and price columns of the dataframe
plt.title('Relation of bedrooms number and price')   # Adding title of the plot
plt.xlabel("bedrooms")   # Adding label of x variable
plt.ylabel("price") # Adding label of y variable
plt.show()  # Showing the plot

# %% [markdown]
# 1) We can see that when it comes to price and grade - when the grade is rising - we can see that the price is also rising by comparing the highest and minimum prices in each grade. However thare are some houses that are overpriced (for example 2 houses with the grade 8 or 1 house with grade 11).
# 2) There is no strong realtion between the price and number of bedrooms. However we can see that there is possibility of buing a house from 0 to 7 bedrooms around the same price.

# %%
#c)
#Your code:
plt.figure(figsize=(16, 9))
plt.scatter(df['zipcode'], df['price'])   # Creating scatter plot from zipcode and price columns of the dataframe
plt.title('Relation of zipcode and price')   # Adding title of the plot
plt.xlabel("zipcode")   # Adding label of x variable
plt.ylabel("price") # Adding label of y variable
plt.ticklabel_format(style='plain') # Removing scientific notation (1e6)
plt.show()  # Showing the plot

# %% [markdown]
# We can see that there are some districs that contain specific prices of houses. For example houses with the zipcode between 98175 abd 98200 came with the low price. On the other hand houses with the zipcodes around 9805 have much highter prices. This might be caused by the neighbourhood or modernisation of each district.

# %%
# #Your code:
plt.scatter(x=df['long'], y=df['lat'], c=df['grade'])   # Creating scatter plot from longitude and latitude columns of the dataframe with a given color according to grade
plt.xlabel("longitude")   # Adding label of x variable
plt.ylabel("latitude") # Adding label of y variable
plt.ticklabel_format(style='plain') # Removing scientific notation (1e6)
plt.colorbar()
plt.rcParams["figure.figsize"] = (17,10) # Changing the size of the plot by using a tuple with width and heigth
plt.show()  # Showing the plot

# %% [markdown]
# By using the scatterplot with the latitude and longitude with the colors according to grade we can see the regions where better graded houses are more common. For example at around 47.65 latitude and -122.3 longitude is a high density of well graded houses which can mean that this is a well developed district or there are many well-kept apartments.

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
df_list = []    # List that will contain data of prices for each grade
labels_list = []        # List that will store the grades labels
grouped_df = df.groupby("grade")        # Grouping the data accorting to the grades
for grade in grouped_df.groups.keys():  # Using loop to get all of the grouped data and labels of grades
        labels_list.append(grade)
        df_list.append(grouped_df.get_group(grade)["price"])
plt.xlabel("grade")   # Adding label of x variable
plt.ylabel("price") # Adding label of y variable
plt.ticklabel_format(style='plain') # Removing scientific notation (1e6)
plt.boxplot(df_list, labels=labels_list) # Creating boxplot using boxplot function
plt.show() # Showing the plot

#Hint: plt.boxplot

# %% [markdown]
# The boxplot gives more information about medians etc. in comparison to the scatterplot. We can still see the rising tendancy of the price according to the grade, but also it shows us the amount of outliers.

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic

#Your code:
mosaic(df, ['grade', 'condition'], title='grade to condition')
plt.show()

# %% [markdown]
# Mosaic plot visualise that around half of the houses have condition 3 and grades around 6-11.

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
from math import floor

df2 = df.loc[(df['bedrooms']==3) & (df['bathrooms']==2) & (df['floors']==2)]    # Using loc function with multiple conditionals
df2.describe()  # Using describe function that gives detailed statistics

#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %% [markdown]
# There are 154 houses that fulfill above constraints and the mean value of square living footage is around 1850. Also around half of the houses have no basement.

# %%
#b)
#Your code:
plt.scatter(df[['grade']],df[['price']], c='black', marker=".", label='All')
plt.scatter(df2[['grade']],df2[['price']], c='y', marker="o", s=100, label='Accepted')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# The yellow dots indicate that all accepted houses are located between 6 and 10 grade.

# %%
#c)
#Your code:
df2 = df.loc[(df['bedrooms']==3) & (df['bathrooms']==2) & (df['floors']==2)].copy()    # Using loc function with multiple conditionals
df2['ratio'] = df2['price'] / df2['sqft_living']    # adding a column with a price to footage ratio
df2 = df2.sort_values('ratio')  # Sorting by ratio values
# df2 = df2.drop(columns=['ratio'])   # Removing ratio column
df2.head(5) # Showing first 5 elements
#Hint: .loc, .sort_values(), .index
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 9704   7452500565  20140829T000000  260000.0         3        2.0
# 11258  7937600262  20140710T000000  379900.0         3        2.0
# 19880  3832050860  20150319T000000  210000.0         3        2.0
# 16014  5104450440  20141113T000000  252500.0         3        2.0
# 20906  3355400242  20141028T000000  274900.0         3        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9704          2710      5000     2.0           0     0  ...        2710
# 11258         3110     44967     2.0           0     0  ...        3020
# 19880         1580      4961     2.0           0     0  ...        1580
# 16014         1810     10684     2.0           0     0  ...        1810
# 20906         1936      6612     2.0           0     0  ...        1936
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# The best 5 price/sqft ratio are houses wich conain exact given criteria of acceptance. The house with id=7452500565 which is around 96 per footage.
